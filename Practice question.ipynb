# %%
student = 'Amit'
print(student)
type(student)
# Out:
# Amit
# str

# %%
marks = 92
print(marks)
type(marks)
# Out:
# 92
# int

# %%
section = 'C'
print(section)
type(section)
# Out:
# C
# str

# %%
list1 = [10,'Hello',5+6j]
list1
# Out:
# [10, 'Hello', (5+6j)]

# %%
tup1 = (500,'Science')
tup1
# Out:
# (500, 'Science')

# %%
dict1 = {'name':'Amit','Section':'C','stream':'Medical'}
dict1
# Out:
# {'name': 'Amit', 'Section': 'C', 'stream': 'Medical'}

# %%
student = 'Priya'
print(student)
type(student)
# Out:
# Priya
# str

# %%
marks = 76
print(marks)
type(marks)
# Out:
# 76
# int

# %%
section = 'B'
print(section)
type(section)
# Out:
# B
# str

# %%
list2 = [45,'World',2+9j]
list2
# Out:
# [45, 'World', (2+9j)]

# %%
tup2 = (700,'Mathematics')
tup2
# Out:
# (700, 'Mathematics')

# %%
dict2 = {'name':'Priya','section':'B','stream':'commerce'}
dict2
# Out:
# {'name': 'Priya', 'section': 'B', 'stream': 'commerce'}
